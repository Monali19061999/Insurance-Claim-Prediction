# %%
#importing
import warnings
warnings.filterwarnings("ignore")
import pandas as pd  #data analysis
import os # importing os module to set the working directory
import seaborn as sns #for data visualization and exploratory data analysis
import numpy as np  #calculations
import matplotlib.pyplot as plt #graph
import scipy.stats as stats #stats
import pylab

# %%
#ingesting data
df = pd.read_csv(r"C:\Users\RAHUL\Desktop\DS_Monali\@SEM2\PPP\Project1\insurance_data.csv") #reading
df
# Out:
#       PatientID   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0             1  39.0    male  23.2             91      Yes         0     No
# 1             2  24.0    male  30.1             87       No         0     No
# 2             3   NaN    male  33.3             82      Yes         0     No
# 3             4   NaN    male  33.7             80       No         0     No
# 4             5   NaN    male  34.1            100       No         0     No
# ...         ...   ...     ...   ...            ...      ...       ...    ...
# 1335       1336  44.0  female  35.5             88      Yes         0    Yes
# 1336       1337  59.0  female  38.1            120       No         1    Yes
# 1337       1338  30.0    male  34.5             91      Yes         3    Yes
# 1338       1339  37.0    male  30.4            106       No         0    Yes
# 1339       1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# 0     southeast   1121.87
# 1     southeast   1131.51
# 2     southeast   1135.94
# 3     northwest   1136.40
# 4     northwest   1137.01
# ...         ...       ...
# 1335  northwest  55135.40
# 1336  northeast  58571.07
# 1337  northwest  60021.40
# 1338  southeast  62592.87
# 1339  southeast  63770.43
#
# [1340 rows x 10 columns]

# %% [markdown]
# Questions:
#
# 1. Are there any missing or zero values? is it possible for it to be zero or missing?
# 2. Is there any relationship between missing values and claim
# 3. How much are the missing values & what is the %? How are u going to deal with it?
# 2. Duplicates?

# %% [markdown]
# ###### Relevance:
# To know whether I really need the information given to us, otherwise our analysis won't be valuable. I want to predict price of the house. let's check what all features are given to me.

# %%
df.columns
# Out:
# Index(['PatientID', 'age', 'gender', 'bmi', 'bloodpressure', 'diabetic',
#        'children', 'smoker', 'region', 'claim'],
#       dtype='object')

# %% [markdown]
# #### Quality:
#     Accuracy-- To know anomalies  --will check this during our EDA
#     Completeness-- To know how comprehensive our information is. ---#No mention on which bloodpressure values are whether systolic or diastolic
#     Reliability--- Trustness --if piece of information contradict another piece of information. eg I will have to check whether claim with same independent variables differs in claim amount
#     Timeliness- -- how upto date our information is. No information is provided. Because as time goes by claim amount will also increase

# %%
df.head()  #to display the first 5 rows of the dataframe
# Out:
#    PatientID   age gender   bmi  bloodpressure diabetic  children smoker  \
# 0          1  39.0   male  23.2             91      Yes         0     No
# 1          2  24.0   male  30.1             87       No         0     No
# 2          3   NaN   male  33.3             82      Yes         0     No
# 3          4   NaN   male  33.7             80       No         0     No
# 4          5   NaN   male  34.1            100       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51
# 2  southeast  1135.94
# 3  northwest  1136.40
# 4  northwest  1137.01

# %% [markdown]
# ### EDA

# %%
df.head() #to display first 5 rows
# Out:
#    PatientID   age gender   bmi  bloodpressure diabetic  children smoker  \
# 0          1  39.0   male  23.2             91      Yes         0     No
# 1          2  24.0   male  30.1             87       No         0     No
# 2          3   NaN   male  33.3             82      Yes         0     No
# 3          4   NaN   male  33.7             80       No         0     No
# 4          5   NaN   male  34.1            100       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51
# 2  southeast  1135.94
# 3  northwest  1136.40
# 4  northwest  1137.01

# %% [markdown]
# #categorizing variables

# %%
print(df.dtypes)
# Out:
# PatientID          int64
# age              float64
# gender            object
# bmi              float64
# bloodpressure      int64
# diabetic          object
# children           int64
# smoker            object
# region            object
# claim            float64
# dtype: object

# %%
# making list of categorical variables  out of all variables 
categorical_variables = [variable for variable in df.columns if df[variable].dtypes == 'O'] 
#for each of the variable in df.column, if datatype of variable is equal to object then it will be categorical variable  

print('Number of categorical variables: ', len(categorical_variables ))

# visualising first 5 rows of the categorical variables 
df[categorical_variables ].head()
# Out:
# Number of categorical variables:  4
#   gender diabetic smoker     region
# 0   male      Yes     No  southeast
# 1   male       No     No  southeast
# 2   male      Yes     No  southeast
# 3   male       No     No  northwest
# 4   male       No     No  northwest

# %%
# making list of numerical variables out of all variables 
numerical_variables = [variable for variable in df.columns if df[variable].dtypes != 'O'] 
#for each of the variable in df.column, if datatype of variable is not equal to object then it will be numerical variable  

print('Number of numerical variables: ', len(numerical_variables))

# visualising first 5 rows of the numerical variables
df[numerical_variables].head()
# Out:
# Number of numerical variables:  6
#    PatientID   age   bmi  bloodpressure  children    claim
# 0          1  39.0  23.2             91         0  1121.87
# 1          2  24.0  30.1             87         0  1131.51
# 2          3   NaN  33.3             82         0  1135.94
# 3          4   NaN  33.7             80         0  1136.40
# 4          5   NaN  34.1            100         0  1137.01

# %%
#discrete variables
discrete_variables=[variable for variable in numerical_variables if len(df[variable].unique())<7]
#for each of the variable in numerical_variables, if unique values of variable are less than 7 then it will be a discrete variable  

print("Discrete Variables Count: {}".format(len(discrete_variables))) #printing no of discrete variables 

# visualising first 5 rows of the discrete variables
df[discrete_variables].head()
# Out:
# Discrete Variables Count: 1
#    children
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
#continuous variables
continuous_variables=[variable for variable in numerical_variables if variable not in discrete_variables + ["date"]]
#for each of the variable in numerical_variables, if variable is not in the discrete_variables then it will be a continuous variable  

print("Continuous variables Count {}".format(len(continuous_variables))) #printing no of continuous variables

# visualising first 5 rows of the continuous variables
df[continuous_variables].head()
# Out:
# Continuous variables Count 5
#    PatientID   age   bmi  bloodpressure    claim
# 0          1  39.0  23.2             91  1121.87
# 1          2  24.0  30.1             87  1131.51
# 2          3   NaN  33.3             82  1135.94
# 3          4   NaN  33.7             80  1136.40
# 4          5   NaN  34.1            100  1137.01

# %% [markdown]
# ### Univariate Analysis
#
# #### Questions:
# 1. What is the description of each variable in the data ?
# 2. what is the distribution form of every variable? what will be the future reference ?
# 3. Whether the variable is leptokurtic or platykurtic or mesokurtic?. what will be the future reference ?
# 4. What is the range of variable? what will be the future reference ?
# 5. Any outliers? Whether they are non-error outliers or error outliers? How are u going to deal with it and why u want to deal with it ?

# %% [markdown]
# #Q3 what is the distribution form of every variable? what will be the future reference ?

# %%
#Univariate for categorical

# %%
for variable in categorical_variables:
    plt.figure()                              #to create a new figure with customizations
    plt.clf()                                 #to clear the entire current figure
    print(df.groupby(variable)[variable].count())
    sns.countplot(df[variable]).set_title('Bar Plot of {}'.format(variable)) #Plotting barplot for column and Setting up the title
# Out:
# gender
# female    662
# male      678
# Name: gender, dtype: int64
# diabetic
# No     698
# Yes    642
# Name: diabetic, dtype: int64
# smoker
# No     1066
# Yes     274
# Name: smoker, dtype: int64
# region
# northeast    231
# northwest    349
# southeast    443
# southwest    314
# Name: region, dtype: int64

# %% [markdown]
# 1. Gender:
#    Almost equal number of female and male policyholders. female- 662 , male- 678
#
# 2. Diabetic:
#    Almost similar number of policyholders for diabetic and non-diabetic. No- 698, Yes- 642
#
# 3. Smoker:
#    More non-smokers than smokers (maybe reason behind highly varying claim amount). No- 1066 , Yes- 274
#
# 4. Region:
#    Policyholders in southeast>northwest>southwest>northeast. southeast- 446, northwest- 349, southwest- 314, northeast- 231

# %%
#Univariate analysis for discrete variable

# %%
for variable in discrete_variables:          #for each variable in discrete_variables do:
        plt.figure()                          #to create a new figure with customizations
        plt.clf()                             #to clear the entire current figure
        sns.countplot(df[variable]).set_title('Bar Plot of '+ variable) #Plotting barplot for column and Setting up the title

# %%
df[discrete_variables].describe()  #statistical summary
# Out:
#           children
# count  1340.000000
# mean      1.093284
# std       1.205334
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       5.000000

# %%
for number in range( min(df['children']), max(df['children'])+1):
    print(str(number) + " children - " ,  len(df[df["children"]==number])/len(df['children'])*100 , " %")
# Out:
# 0 children -  42.98507462686567  %
# 1 children -  24.17910447761194  %
# 2 children -  17.91044776119403  %
# 3 children -  11.716417910447761  %
# 4 children -  1.8656716417910446  %
# 5 children -  1.3432835820895521  %

# %% [markdown]
# #Analysis:
#
#     Range = 0 to 5
#     children(0>1>2>3>4>5)
#     Policyholder on an average have 1 child
#     Number of policyholders with no or 1 or 2 children are ~86%
#     Number of policyholders with 3 or 4 children are ~14%

# %%
#Univariate analysis of continuous variables
df[continuous_variables].describe()  #statistical summary
# Out:
#          PatientID          age          bmi  bloodpressure         claim
# count  1340.000000  1335.000000  1340.000000    1340.000000   1340.000000
# mean    670.500000    38.078652    30.668955      94.157463  13252.745642
# std     386.968991    11.102924     6.106735      11.434712  12109.609288
# min       1.000000    18.000000    16.000000      80.000000   1121.870000
# 25%     335.750000    29.000000    26.275000      86.000000   4719.685000
# 50%     670.500000    38.000000    30.400000      92.000000   9369.615000
# 75%    1005.250000    47.000000    34.700000      99.000000  16604.305000
# max    1340.000000    60.000000    53.100000     140.000000  63770.430000

# %%
for variable in continuous_variables:          #for each variable in continuous_variables do:
    fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=fig_dims)
    sns.distplot(df[variable], kde=True, ax=axs[0])   #plot histogram
    sns.boxplot(x= variable, data=df, ax=axs[1])   #plot boxplot
    print("skewness for {} = {}".format(variable, df[variable].skew()))  #print skewness
    print("Kurtosis for {}= {}".format(variable, df[variable].kurtosis()))  #print kurtosis
    print("CV for {}= {}".format(variable, df[variable].mean()/df[variable].std()))  #print CV
# Out:
# skewness for PatientID = 0.0
# Kurtosis for PatientID= -1.2
# CV for PatientID= 1.7326969746525642
# skewness for age = 0.11361133741072633
# Kurtosis for age= -0.9470236326886194
# CV for age= 3.4296057589413103
# skewness for bmi = 0.28597245020808587
# Kurtosis for bmi= -0.060200212623761296
# CV for bmi= 5.022152818950827
# skewness for bloodpressure = 1.4835342102293079
# Kurtosis for bloodpressure= 2.890031852235991
# CV for bloodpressure= 8.234353845786819
# skewness for claim = 1.5167468509489237
# Kurtosis for claim= 1.6102462646376146
# CV for claim= 1.0943991112097826

# %%
len(df)
# Out:
# 1340

# %% [markdown]
# ### Missing Values

# %%
#checking missing values
print(df.isnull().sum()) 

print("")
print("%of missing values")
print("")

#here checking percentage of missing values present in each variable
for column in df.columns: #for each column in data
    null = (sum(df[column].isnull())/len(df[column])) * 100  #calculating % of null values 
    print(column, null) # printing variable name and %of missing values
# Out:
# PatientID        0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64
#
# %of missing values
#
# PatientID 0.0
# age 0.3731343283582089
# gender 0.0
# bmi 0.0
# bloodpressure 0.0
# diabetic 0.0
# children 0.0
# smoker 0.0
# region 0.22388059701492538
# claim 0.0

# %% [markdown]
# Yes we have missing values in age and region. It's not possible to have these values missing. so we will impute them

# %%
#### Imputing missing values
#for region- replacing with mode
mode= df['region'].mode()[0]
df['region'].fillna(mode, inplace=True)
df['region']
# Out:
# 0       southeast
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1335    northwest
# 1336    northeast
# 1337    northwest
# 1338    southeast
# 1339    southeast
# Name: region, Length: 1340, dtype: object

# %%
#creating function for imputing missing values with mean
def impute_nan(df,variable,mean):
    df[variable+"_mean"]=df[variable].fillna(mean)

# %%
#calculation of mean for age column
mean=df.age.mean()
#imputing with mean
impute_nan(df,'age',mean)
df.head()
# Out:
#    PatientID   age gender   bmi  bloodpressure diabetic  children smoker  \
# 0          1  39.0   male  23.2             91      Yes         0     No
# 1          2  24.0   male  30.1             87       No         0     No
# 2          3   NaN   male  33.3             82      Yes         0     No
# 3          4   NaN   male  33.7             80       No         0     No
# 4          5   NaN   male  34.1            100       No         0     No
#
#       region    claim   age_mean
# 0  southeast  1121.87  39.000000
# 1  southeast  1131.51  24.000000
# 2  southeast  1135.94  38.078652
# 3  northwest  1136.40  38.078652
# 4  northwest  1137.01  38.078652

# %%
#after imputation checking by how much amount variance is changed 
print(df['age'].std())
print(df['age_mean'].std())
# Out:
# 11.102923881591513
# 11.082174613072029

# %%
# there's almost no change in original variance
import matplotlib.pyplot as plt
# %matplotlib inline
#checking distribution of age and age_mean (ie age after imputation)
fig = plt.figure()
ax = fig.add_subplot(111)
df['age'].plot(kind='kde', ax=ax)
df.age_mean.plot(kind='kde', ax=ax, color='red')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

#kde=kernel density estimator

# %%
# age_mean is above age in the middle because we replaced nan with mean & mean~ median
#checking again for any null values
print(df.isnull().sum())
# Out:
# PatientID        0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           0
# claim            0
# age_mean         0
# dtype: int64

# %%
#dropping unnecessary columns
df = df.drop('PatientID',axis=1)  #dropping id column
df = df.drop('age',axis=1) #dropping age column as we have age column with imputed mean

# %%
continuous_variables=[ 'age_mean', 'bmi', 'bloodpressure', 'claim']

# %% [markdown]
# ### Bivariate analysis & Hypothesis testing

# %% [markdown]
# #### Steps:
#
# ##### 1. Visualization
# ##### 2. Descriptive Statistics
# ##### 3. Hypothesis Testing

# %% [markdown]
# #### Initial Questions:
# 1. How each independent feature is related with claim?     ---
# 2. Do older policyholders have high claim amount?          ---
# 2. How is the gender related with claim amount?      ----
# 3. Policyholders who are not falling in normal BMI range(ie BMI < 18.5 & BMI > 24.9) have higher claim amount?  ----
# 5. Do policyholders with higher bloodpressure have higher claim amount?   ----(>120 / >80
# 6. Do policyholders who are diabetic claim higher amount?            ----
# 7. Do policyholders with higher number of children have higher claim amount ?
# 8. Do policyholders who smoke have higher claim amount?                        ----
# 9. Do policyholders belonging to specific region have higher claim amount or less claim amount?  ----
# 10. Is their correlation between independent variables? if yes how will u handle it?
# 11. Which variables are correlated with claim?  ----
# 12. According to studies, smoking, diabetes and higher bmi leads to high bloodpressure. Do our data also shows same? If yes then what will be future reference? -----
# 13. Whether smoking is gender influenced?----
# 14. Is the BMI of females different than the BMI of males?

# %% [markdown]
# ##### Initial thoughts according to research:
#
# 1. more age ------>     more claim amount
# 2. bmi ------------>   18.5 - 24.9------>less claim amount , <18.5 & >24.9 ----> higher claim amount
# 3. bloodpressure --->   between 90/60 to 120/80 ------> lower claim amount, <90/60 & >120/80 -----> higher claim amount
# 4. diabetic -------->    yes-  higher claim amount,  no-- less claim amount
# 5. children -------->  more the number of children ---Higher the claim amount
# 6. smoker ---------> yes-higher claim amount, no-less claim amount

# %% [markdown]
# ##### Bivariate analysis of each variable with target variable

# %%
#correlation

plt.figure(figsize=(15, 15))
cor=df.corr()
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#     here, claim is
#     highly correlated with-
#     moderate correlation with-    bloodpressure
#     weak correlation with-        bmi
#     no correlation with-          age, children

# %%
#This gives us how variables are related to each other. 
from pandas.plotting import scatter_matrix
scatter_matrix(df,alpha = 0.5,
               figsize = (14,10),diagonal = 'hist')
plt.show()

# %%
#Bivariate analysis of categorical variables with claim
#Visualization
for variable in categorical_variables:
    fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, figsize=fig_dims)
    sns.boxplot(data = df, x = df[variable], y = "claim" )

# %%
#Descriptive stat
for variable in categorical_variables:
    print( df.groupby([variable])['claim'].agg(["mean"]))
# Out:
#                 mean
# gender
# female  12569.578897
# male    13919.790457
#                   mean
# diabetic
# No        13354.031991
# Yes       13142.624346
#                 mean
# smoker
# No       8421.121576
# Yes     32050.231971
#                    mean
# region
# northeast  16889.044719
# northwest  11672.088453
# southeast  12979.121502
# southwest  12723.129841

# %% [markdown]
# ### Insights:
#
# 1. Gender :
#
# Average claim amount of male is more than female. The distribution of values for male and female before median look similar but after median it's different male are more likely to claim higher than female. Medians appear close. Male policy holder has incure more claim amount compared to female policy holder. There are lot of outliers in female policy holder. So mean(female) may be different from mean(male). Need to check this using hypothesis testing.
#
# 4. Diabetic :
#
# Average claim amount for diabetic & non-diabetic is almost same. The distribution of values for diabetic and non-diabetic look similar and their medians appear close. There is very high chance there means will not be far away. So mean(diabetic) may not be different from mean(non-diabetic).
#
# 3. Smoker :
#
# Average claim amount of smoker is very high than non-smoker. The distribution of values for smokers and non-smokers look dissimilar and their medians also appear away. So there is very high chance means will be away. So mean(smokers) may be different from mean(smokers)
#
# 2. Region :
#
# Average claim amount of northeast is high as compared to other 3 regions.The distribution of values looks similar for northwest and southwest but distibution for southeast and northeast does not look very similar with other two; medians for northwest, southeast, southwest also looks similar but northeast median is not very similar with other three. So. northeast may have different mean as compared with the other three regions

# %%
#bivariate analysis of discrete variables with claim
for variable in discrete_variables:
    fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, figsize=fig_dims)
    sns.boxplot(data = df, x = df[variable], y = "claim" )

# %%
df.groupby(['children'])['claim'].agg(["mean"])
# Out:
#                   mean
# children
# 0         12327.993160
# 1         12731.171821
# 2         15073.564000
# 3         15355.318535
# 4         13850.656800
# 5          8786.035556

# %% [markdown]
# #### Insights:
# 1. Incresing trend in claim as number of children increases upto 3 and later decreases. Why? It should increase
# 2. Medians do look close to each other

# %%
#Bivariate analysis of continuous variables with claim
for variable in continuous_variables:
    sns.regplot(x= variable, y='claim', data=df)
    plt.legend(loc=(0))
    plt.figure(figsize=(8, 4))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
#Checking for balance in our data for gender category
df['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Male & female in our dataset are quiet balanced

# %% [markdown]
# #### This is 2 independent population mean test
#
# ##### Here we don't know both populations standard deviations so we will use t-test
#
# ##### H0: mu_male = mu_female ie mu_male - mu_female = 0
# ##### H1: mu_male <> mu_female  ie mu_male - mu_female <> 0   #2 tail test

# %%
#To know sample mean
print(df.groupby(["gender"])["claim"].agg(["mean"]))
print(df.groupby(["gender"])["claim"].agg(["count"]))
print(df.groupby(["gender"])["claim"].agg(["std"]))
# Out:
#                 mean
# gender
# female  12569.578897
# male    13919.790457
#         count
# gender
# female    662
# male      678
#                  std
# gender
# female  11128.703817
# male    12969.700466

# %%
alpha =0.05 
n_male = 678    # n > 30
n_female = 662  # n > 30
mean_male = 13919.79
mean_female = 12569.57
std_male=12969.700466
std_female=12969.700466

# %%
t_stat= ((mean_male-mean_female)-0)/((std_male**2/n_male)+(std_female**2/n_female))**0.5
print("t_stat= ", t_stat)
df = (((std_male**2/n_male)+(std_female**2/n_female))**2/(((std_male**2/n_male)**2/(n_male-1))+ ((std_female**2/n_female)**2/(n_female-1)) ))
print("df= ", df)
t_crit_u= stats.t.isf(alpha/2, df)
print('t_crit_u=', t_crit_u)
t_crit_l= stats.t.cdf(alpha/2, df)
print('t_crit_l=', t_crit_l)
# Out:
# t_stat=  1.9053116936575532
# df=  1337.2361475038917
# t_crit_u= 1.9617395747081805
# t_crit_l= 0.5099706532033178

# %%
p_value_u= 2*stats.t.sf(t_stat, df)
print("p_value_u= ", p_value_u)
# Out:
# p_value_u=  0.056953873138835424

# %%
if t_stat >= t_crit_u or t_stat <= t_crit_l :
    print("Reject H0. So, mu_male is not equal to mu_female ")
else:
    print("Accept H0. So, mu_male is equal to mu_female")
    
if alpha >=  p_value_u:
    print("Reject H0. So, mu_male is not equal to mu_female")
else:
    print("Accept H0. So, mu_male is equal to mu_female")
# Out:
# Accept H0. So, mu_male is equal to mu_female
# Accept H0. So, mu_male is equal to mu_female

# %% [markdown]
# #### One way Anova   - region & claim
#
#     (because here populations will be 4)
#       Null Hypothesis H0 – There is no significant difference among the groups
#       Alternate Hypothesis – There is a significant difference among the groups

# %%
n_e=df[df.region=='northeast'].claim
n_w=df[df.region=='northwest'].claim
s_e=df[df.region=='southeast'].claim
s_w=df[df.region=='southwest'].claim

# %%
# normality tests
print(stats.shapiro(n_e))
print(stats.shapiro(n_w))
print(stats.shapiro(s_e))
print(stats.shapiro(s_w))
# Out:
# ShapiroResult(statistic=0.8777790069580078, pvalue=1.1079376348657743e-12)
# ShapiroResult(statistic=0.8072879314422607, pvalue=4.46119248488647e-20)
# ShapiroResult(statistic=0.7731466889381409, pvalue=2.240676768100462e-24)
# ShapiroResult(statistic=0.7853246927261353, pvalue=5.0216186590010836e-20)

# %%
# variance equality test
stats.levene(n_e, n_w, s_e, s_w)
# Out:
# LeveneResult(statistic=1.3611645100759595, pvalue=0.25308088982987537)

# %%
#normality test failed trying to replace outlier

#Replacing outlier

IQR = n_e.quantile(0.75)- n_e.quantile(0.25) #computing the Interquantile range to calculate the boundaries

lower_bridge=n_e.quantile(0.25)-(IQR*1.5)
upper_bridge=n_e.quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)


IQR = n_w.quantile(0.75)-n_w.quantile(0.25) #computing the Interquantile range to calculate the boundaries

lower_bridge=n_w.quantile(0.25)-(IQR*1.5)
upper_bridge=n_w.quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)

IQR = s_e.quantile(0.75)-s_e.quantile(0.25) #computing the Interquantile range to calculate the boundaries
lower_bridge=s_e.quantile(0.25)-(IQR*1.5)
upper_bridge=s_e.quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)

IQR = s_w.quantile(0.75)-s_w.quantile(0.25) #computing the Interquantile range to calculate the boundaries
lower_bridge=s_w.quantile(0.25)-(IQR*1.5)
upper_bridge=s_w.quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# -8770.615000000003
# 40007.38500000001
# -11301.315
# 29588.165
# -14486.6575
# 35778.6025
# -8185.1799999999985
# 27053.64
# (None, None)

# %%
#Replacing outliers
n_e.loc[n_e>40007.38500000001]=40007.38500000001
print(n_e.skew())
n_w.loc[n_w>29588.165]=29588.165
print(n_w.skew())
s_e.loc[s_e>35778.6025]=35778.6025
print(s_e.skew())
s_w.loc[s_w>27053.64]=27053.64
print(s_w.skew())
# Out:
# 0.9458617418526478
# 1.002832656562103
# 1.2028924517691602
# 0.9018988416957259

# %%
# normality tests
print(stats.shapiro(n_e))
print(stats.shapiro(n_w))
print(stats.shapiro(s_e))
print(stats.shapiro(s_w))
# Out:
# ShapiroResult(statistic=0.8807350993156433, pvalue=1.660364445758844e-12)
# ShapiroResult(statistic=0.8579744696617126, pvalue=2.6515337401113856e-17)
# ShapiroResult(statistic=0.7898043990135193, pvalue=1.4207501654444395e-23)
# ShapiroResult(statistic=0.8693127632141113, pvalue=1.1790296285129915e-15)

# %%
#applying log transformation
n_e=np.log(n_e)
n_w=np.log(n_w)
s_e=np.log(s_e)
s_w=np.log(s_w)

# %%
print(n_e.skew())
print(n_w.skew())
print(s_e.skew())
print(s_w.skew())
# Out:
# -0.6589554814621934
# -0.24482786259078856
# 0.04566305500594509
# -0.3483843915030724

# %%
# normality tests
print(stats.shapiro(n_e))
print(stats.shapiro(n_w))
print(stats.shapiro(s_e))
print(stats.shapiro(s_w))
# Out:
# ShapiroResult(statistic=0.9347296953201294, pvalue=1.3002543042262005e-08)
# ShapiroResult(statistic=0.9611306190490723, pvalue=5.3014218792668544e-08)
# ShapiroResult(statistic=0.961383581161499, pvalue=1.9758752412002423e-09)
# ShapiroResult(statistic=0.9597620964050293, pvalue=1.304681802594132e-07)

# %%
result= stats.kruskal(n_e, n_w, s_e, s_w )
print(result)
# Out:
# KruskalResult(statistic=70.36606095838819, pvalue=3.563453794150216e-15)

# %% [markdown]
# Since, pvalue is less than 0.05 we reject the null hypothesis.
# ##### Hence region affect claim amount But from our descriptive stats except northeast region, other regions had almost similar amounts lets check

# %%
result= stats.kruskal( n_w, s_e, s_w )
print(result)
# Out:
# KruskalResult(statistic=2.243605240705952, pvalue=0.32569216581942984)

# %% [markdown]
# Since, pvalue is more than 0.05 we reject the null hypothesis.

# %% [markdown]
# ##### Hence except northeast all others region claim amount is same

# %% [markdown]
# #### One way Anova   - children & claim
#       Null Hypothesis H0 – There is no significant difference among the groups
#       Alternate Hypothesis – There is a significant difference among the groups

# %%
c_0=df[df.children==0].claim
c_1=df[df.children==1].claim
c_2=df[df.children==2].claim
c_3=df[df.children==3].claim
c_4=df[df.children==4].claim
c_5=df[df.children==5].claim

# %%
# normality tests
print(stats.shapiro(c_0))
print(stats.shapiro(c_1))
print(stats.shapiro(c_2))
print(stats.shapiro(c_3))
print(stats.shapiro(c_4))
print(stats.shapiro(c_5))
# Out:
# ShapiroResult(statistic=0.8162412643432617, pvalue=4.098972046449151e-25)
# ShapiroResult(statistic=0.7752900123596191, pvalue=8.85195296399475e-21)
# ShapiroResult(statistic=0.7951909303665161, pvalue=4.783164282026247e-17)
# ShapiroResult(statistic=0.8057760000228882, pvalue=3.635229053541855e-13)
# ShapiroResult(statistic=0.8294430375099182, pvalue=0.0007348806248046458)
# ShapiroResult(statistic=0.890959620475769, pvalue=0.040083467960357666)

# %%
# variance equality test
stats.levene(c_0, c_1, c_2, c_3, c_4, c_5)
# Out:
# LeveneResult(statistic=2.0829171575561305, pvalue=0.06501341527146635)

# %%
#applying log transformation
c_0=np.log(c_0)
c_1=np.log(c_1)
c_2=np.log(c_2)
c_3=np.log(c_3)
c_4=np.log(c_4)
c_5=np.log(c_5)

# %%
# normality tests
print(stats.shapiro(c_0))
print(stats.shapiro(c_1))
print(stats.shapiro(c_2))
print(stats.shapiro(c_3))
print(stats.shapiro(c_4))
print(stats.shapiro(c_5))
# Out:
# ShapiroResult(statistic=0.9531512260437012, pvalue=1.4832315063662005e-12)
# ShapiroResult(statistic=0.9767917394638062, pvalue=4.309538780944422e-05)
# ShapiroResult(statistic=0.9527884125709534, pvalue=4.7249355361600465e-07)
# ShapiroResult(statistic=0.961079478263855, pvalue=0.00021472030493896455)
# ShapiroResult(statistic=0.967096209526062, pvalue=0.5726698637008667)
# ShapiroResult(statistic=0.953526496887207, pvalue=0.4829793870449066)

# %% [markdown]
# #### As c_0, c_1, c_2, c_3 are not meeting normality test criteria we can't use one way anova So, using Kruskal Wallis test

# %% [markdown]
#     H0:  n_e, n_w, s_e, s_w all 4 populations are identical distibution (ie all 4 have same probability distribution)
#     H1: Not identical distribution

# %%
result= stats.kruskal(c_0, c_1, c_2, c_3, c_4, c_5)
print(result)
# Out:
# KruskalResult(statistic=30.231923632873826, pvalue=1.3276517529776629e-05)

# %% [markdown]
# Since, pvalue is less than 0.05 we reject the null hypothesis.
# ##### Hence children affect claim amount

# %% [markdown]
# ### What if we consider different groups for children?

# %%
result= stats.kruskal(c_2, c_3, c_4, c_5)
print(result)
# Out:
# KruskalResult(statistic=4.2258051019096, pvalue=0.2380909709186021)

# %%
result= stats.kruskal( c_0, c_1)
print(result)
# Out:
# KruskalResult(statistic=2.1729631650570105, pvalue=0.1404553666160414)

# %% [markdown]
# ### Hence policyholders with 0 &1 children have similar claim amount while 2, 3,4,5 have similar claim amount

# %%
#Descriptive stats
for variable in ['diabetic', 'smoker', 'children']:
    print(pd.crosstab(index=df['gender'], columns=df[variable],normalize="index"))
    print("")
# Out:
# diabetic        No       Yes
# gender
# female    0.512085  0.487915
# male      0.529499  0.470501
#
# smoker        No       Yes
# gender
# female  0.826284  0.173716
# male    0.765487  0.234513
#
# children         0         1         2         3         4         5
# gender
# female    0.436556  0.238671  0.179758  0.116314  0.016616  0.012085
# male      0.423304  0.244838  0.178466  0.117994  0.020649  0.014749

# %% [markdown]
# ##### Performing chi-square test of independence

# %%
data_ht= df.copy()
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
data_ht['gender']= le.fit_transform(data_ht['gender'])  #male is 1 female is 0
data_ht['smoker']= le.fit_transform(data_ht['smoker'])  #smoker is 1 non-smoker is 0

# %%
obs_table= pd.crosstab(data_ht['smoker'], data_ht['gender'])
obs_table=obs_table.values
print("obs_table= \n", obs_table)
gender_tot= np.array([len(data_ht['gender'])-sum(data_ht['gender']), sum(data_ht['gender'])])
smoking_tot=np.array([len(data_ht['smoker'])-sum(data_ht['smoker']), sum(data_ht['smoker'] )])
total=sum(gender_tot)
print("gender_tot= ", gender_tot) 
print("smoking_tot= ", smoking_tot) 
print("total=       ", total) 
exp_table= [  gender_tot*smoking_tot[0]/total,
    gender_tot*smoking_tot[1]/total ]
print("exp_table= ", exp_table)
#chi statistc
Chi_stat= np.sum(((obs_table[0,:]- exp_table[0])**2)/exp_table[0]) + np.sum(((obs_table[1,:]-exp_table[1])**2)/exp_table[1])
print("Chi_stat= ", Chi_stat)
#degrees of freedom
no_of_rows= len(smoking_tot)
no_of_columns=len(gender_tot)
df=(no_of_rows-1)*(no_of_columns-1)
print('df= ', df)
#considering 0.05 significance level
alpha=0.05
Chi_crit=stats.chi2.isf(0.05, df)
print("Chi_crit= ", Chi_crit)
p_value= stats.chi2.sf(Chi_stat, df)
print("p_value= ", p_value)
if Chi_stat >= Chi_crit:
    print("Reject H0. There is a relationship between gender and smoking")
else:
    print("Accept H0. There is no relationship between gender and smoking")
    
if alpha >= p_value:
    print("Reject H0. There is a relationship between  gender and smoking")
else:
    print("Accept H0. There is no relationship between gender and smoking")
# Out:
# obs_table=
#  [[547 519]
#  [115 159]]
# gender_tot=  [662 678]
# smoking_tot=  [1066  274]
# total=        1340
# exp_table=  [array([526.6358209, 539.3641791]), array([135.3641791, 138.6358209])]
# Chi_stat=  7.611193450221007
# df=  1
# Chi_crit=  3.8414588206941285
# p_value=  0.005800707916012198
# Reject H0. There is a relationship between gender and smoking
# Reject H0. There is a relationship between  gender and smoking

# %%
#Bivariate analysis of continuous variables with gender
#visualization
for variable in continuous_variables:
    fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, figsize=fig_dims)
    sns.boxplot(data = df, x = df['gender'], y = df[variable] )

# %%
#Descriptive stat
for variable in continuous_variables:
    print(variable, df.groupby(["gender"])[variable].agg(["mean"]))
    print("")
# Out:
# age_mean              mean
# gender
# female  42.483384
# male    33.777866
#
# bmi              mean
# gender
# female  30.379758
# male    30.951327
#
# bloodpressure              mean
# gender
# female  94.013595
# male    94.297935
#
# claim                 mean
# gender
# female  12569.578897
# male    13919.790457

# %%
#To know sample mean
print(df.groupby(["gender"])["age_mean"].agg(["mean"]))
print(df.groupby(["gender"])["age_mean"].agg(["count"]))
print(df.groupby(["gender"])["age_mean"].agg(["std"]))
# Out:
#              mean
# gender
# female  42.483384
# male    33.777866
#         count
# gender
# female    662
# male      678
#               std
# gender
# female  10.786704
# male     9.581704

# %%
alpha =0.05 
n_male = 678    # n > 30
n_female = 662  # n > 30
mean_male = 33.777866
mean_female = 42.483384
std_male= 9.581704
std_female=10.786704

# %%
t_stat= ((mean_male-mean_female)-0)/((std_male**2/n_male)+(std_female**2/n_female))**0.5
print("t_stat= ", t_stat)
df = (((std_male**2/n_male)+(std_female**2/n_female))**2/(((std_male**2/n_male)**2/(n_male-1))+ ((std_female**2/n_female)**2/(n_female-1)) ))
print("df= ", df)
t_crit_u= stats.t.isf(alpha/2, df)
print('t_crit_u=', t_crit_u)
t_crit_l= stats.t.cdf(alpha/2, df)
print('t_crit_l=', t_crit_l)
# Out:
# t_stat=  -15.606114868858223
# df=  1311.6873613240668
# t_crit_u= 1.9617741906866981
# t_crit_l= 0.5099706168808452

# %%
p_value_u= 2*stats.t.cdf(t_stat, df)
print("p_value_u= ", p_value_u)
# Out:
# p_value_u=  1.711085229401062e-50

# %%
if t_stat >= t_crit_u or t_stat <= t_crit_l :
    print("Reject H0. So, mu_male is not equal to mu_female ")
else:
    print("Accept H0. So, mu_male is equal to mu_female")
    
if alpha >=  p_value_u:
    print("Reject H0. So, mu_male is not equal to mu_female")
else:
    print("Accept H0. So, mu_male is equal to mu_female")
# Out:
# Reject H0. So, mu_male is not equal to mu_female
# Reject H0. So, mu_male is not equal to mu_female

# %% [markdown]
# #### Hence Gender do play role here

# %% [markdown]
# ###### Region

# %%
#Bivariate analysis of discrete & categorical variables with region
#Visualization
for variable in ['diabetic', 'smoker', 'children', 'gender']:
    ax=pd.crosstab(df['region'], df[variable]).plot(kind='bar', stacked=True)

# %%
#Descriptive stats
for variable in ['diabetic', 'smoker', 'children', 'gender']:
    print(pd.crosstab(index=df['region'], columns=df[variable],normalize="index"))
    print("")
# Out:
# diabetic         No       Yes
# region
# northeast  0.476190  0.523810
# northwest  0.550143  0.449857
# southeast  0.506726  0.493274
# southwest  0.541401  0.458599
#
# smoker           No       Yes
# region
# northeast  0.709957  0.290043
# northwest  0.833811  0.166189
# southeast  0.795964  0.204036
# southwest  0.815287  0.184713
#
# children          0         1         2         3         4         5
# region
# northeast  0.454545  0.246753  0.160173  0.108225  0.025974  0.004329
# northwest  0.441261  0.217765  0.189112  0.131805  0.017192  0.002865
# southeast  0.423767  0.255605  0.179372  0.109865  0.013453  0.017937
# southwest  0.407643  0.245223  0.181529  0.117834  0.022293  0.025478
#
# gender       female      male
# region
# northeast  0.484848  0.515152
# northwest  0.469914  0.530086
# southeast  0.502242  0.497758
# southwest  0.515924  0.484076

# %% [markdown]
# ##### Performing hypothesis on region & diabetic condition

# %% [markdown]
# #### This is Chi square test of independence

# %% [markdown]
#      Whether diabetic condition is region influenced?
#             H0: region do not influences diabetic condition
#             Ha: region do influences diabetic condition

# %%
data_ht= df.copy()
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
data_ht['region']= le.fit_transform(data_ht['region'])  
data_ht['diabetic']= le.fit_transform(data_ht['diabetic'])

# %%
obs_table= pd.crosstab(data_ht['diabetic'], data_ht['region'])
obs_table=obs_table.values
print("obs_table= \n", obs_table)
region_tot= obs_table[0] + obs_table[1]
diabetic_tot=obs_table[:, 0] + obs_table[:, 1] + obs_table[:, 2] +obs_table[:, 3]  
total=sum(region_tot)
print("region_tot= ", region_tot) 
print("diabetic_tot= ", diabetic_tot) 
print("total=       ", total) 
exp_table= [region_tot*diabetic_tot[0]/total,
    region_tot*diabetic_tot[1]/total ]
print("exp_table= ", exp_table)
#chi statistc
Chi_stat= np.sum(((obs_table[0,:]- exp_table[0])**2)/exp_table[0]) + np.sum(((obs_table[1,:]-exp_table[1])**2)/exp_table[1])
print("Chi_stat= ", Chi_stat)
#degrees of freedom
no_of_rows= len(diabetic_tot)
no_of_columns=len(region_tot)
df=(no_of_rows-1)*(no_of_columns-1)
print('df= ', df)
#considering 0.05 significance level
alpha=0.05
Chi_crit=stats.chi2.isf(0.05, df)
print("Chi_crit= ", Chi_crit)
p_value= stats.chi2.sf(Chi_stat, df)
print("p_value= ", p_value)
if Chi_stat >= Chi_crit:
    print("Reject H0. Region do influences diabetic condition")
else:
    print("Accept H0. Region do not influences diabetic condition")
    
if alpha >= p_value:
    print("Reject H0. Region do influences diabetic condition")
else:
    print("Accept H0. Region do not influences diabetic condition")
# Out:
# obs_table=
#  [[110 192 226 170]
#  [121 157 220 144]]
# region_tot=  [231 349 446 314]
# diabetic_tot=  [698 642]
# total=        1340
# exp_table=  [array([120.32686567, 181.79253731, 232.31940299, 163.56119403]), array([110.67313433, 167.20746269, 213.68059701, 150.43880597])]
# Chi_stat=  3.933994087403091
# df=  3
# Chi_crit=  7.814727903251178
# p_value=  0.2686803522162552
# Accept H0. Region do not influences diabetic condition
# Accept H0. Region do not influences diabetic condition

# %% [markdown]
# ##### Performing hypothesis on region & smoking
#
# ###### Chi square test of independents

# %% [markdown]
#      Whether smoking is region influenced?
#             H0: region do not influences smoking
#             Ha: region do influences smoking

# %%
# data_h= df.copy()
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
data_ht['region']= le.fit_transform(data_ht['region']) 
data_ht['smoker']= le.fit_transform(data_ht['smoker'])

# %%
obs_table= pd.crosstab(data_ht['smoker'], data_ht['region'])
print(obs_table)
obs_table=obs_table.values
print("obs_table= \n", obs_table)
region_tot= obs_table[0] + obs_table[1]
smoker_tot=obs_table[:, 0] + obs_table[:, 1] + obs_table[:, 2] +obs_table[:, 3]  
total=sum(region_tot)
print("region_tot= ", region_tot) 
print("smoker_tot= ", smoker_tot) 
print("total=       ", total) 
exp_table= [region_tot*smoker_tot[0]/total,
    region_tot*smoker_tot[1]/total ]
print("exp_table= ", exp_table)
#chi statistc
Chi_stat= np.sum(((obs_table[0,:]- exp_table[0])**2)/exp_table[0]) + np.sum(((obs_table[1,:]-exp_table[1])**2)/exp_table[1])
print("Chi_stat= ", Chi_stat)
#degrees of freedom
no_of_rows= len(smoker_tot)
no_of_columns=len(region_tot)
df=(no_of_rows-1)*(no_of_columns-1)
print('df= ', df)
#considering 0.05 significance level
alpha=0.05
Chi_crit=stats.chi2.isf(0.05, df)
print("Chi_crit= ", Chi_crit)
p_value= stats.chi2.sf(Chi_stat, df)
print("p_value= ", p_value)
if Chi_stat >= Chi_crit:
    print("Reject H0. Region do influences smoking")
else:
    print("Accept H0. Region do not influences smoking ")
    
if alpha >= p_value:
    print("Reject H0. Region do influences smoking")
else:
    print("Accept H0. Region do not influences smoking")
# Out:
# region    0    1    2    3
# smoker
# 0       164  291  355  256
# 1        67   58   91   58
# obs_table=
#  [[164 291 355 256]
#  [ 67  58  91  58]]
# region_tot=  [231 349 446 314]
# smoker_tot=  [1066  274]
# total=        1340
# exp_table=  [array([183.76567164, 277.63731343, 354.80298507, 249.79402985]), array([47.23432836, 71.36268657, 91.19701493, 64.20597015])]
# Chi_stat=  14.297002475827984
# df=  3
# Chi_crit=  7.814727903251178
# p_value=  0.0025275302069715615
# Reject H0. Region do influences smoking
# Reject H0. Region do influences smoking

# %% [markdown]
# ### Is this result because of northeast? Let's check by doing hypothesis on the regions except northeast

# %%
pd.crosstab(df['smoker'], df['region'])
# Out:
# region  northeast  northwest  southeast  southwest
# smoker
# No            164        291        355        256
# Yes            67         58         91         58

# %%
data_ht2=df[df['region'] != 'northeast']

# %%
obs_table= pd.crosstab(data_ht2['smoker'], data_ht2['region'])
print(obs_table)
obs_table=obs_table.values
print("obs_table= \n", obs_table)
region_tot= obs_table[0] + obs_table[1]
smoker_tot=obs_table[:, 0] + obs_table[:, 1] + obs_table[:, 2]  
total=sum(region_tot)
print("region_tot= ", region_tot) 
print("smoker_tot= ", smoker_tot) 
print("total=       ", total) 
exp_table= [region_tot*smoker_tot[0]/total,
    region_tot*smoker_tot[1]/total ]
print("exp_table= ", exp_table)
#chi statistc
Chi_stat= np.sum(((obs_table[0,:]- exp_table[0])**2)/exp_table[0]) + np.sum(((obs_table[1,:]-exp_table[1])**2)/exp_table[1])
print("Chi_stat= ", Chi_stat)
#degrees of freedom
no_of_rows= len(smoker_tot)
no_of_columns=len(region_tot)
df=(no_of_rows-1)*(no_of_columns-1)
print('df= ', df)
#considering 0.05 significance level
alpha=0.05
Chi_crit=stats.chi2.isf(0.05, df)
print("Chi_crit= ", Chi_crit)
p_value= stats.chi2.sf(Chi_stat, df)
print("p_value= ", p_value)
if Chi_stat >= Chi_crit:
    print("Reject H0. Region do influences smoking")
else:
    print("Accept H0. Region do not influences smoking ")
    
if alpha >= p_value:
    print("Reject H0. Region do influences smoking")
else:
    print("Accept H0. Region do not influences smoking")
# Out:
# region  northwest  southeast  southwest
# smoker
# No            291        355        256
# Yes            58         91         58
# obs_table=
#  [[291 355 256]
#  [ 58  91  58]]
# region_tot=  [349 446 314]
# smoker_tot=  [902 207]
# total=        1109
# exp_table=  [array([283.85752931, 362.75202885, 255.39044184]), array([65.14247069, 83.24797115, 58.60955816])]
# Chi_stat=  1.8581705386135385
# df=  2
# Chi_crit=  5.991464547107983
# p_value=  0.39491478587885376
# Accept H0. Region do not influences smoking
# Accept H0. Region do not influences smoking

# %% [markdown]
# ### Yes. It is true. So, proportion of smokers is more in northeast & for all other regions ,it's same

# %% [markdown]
# #### Can we say that smoking can explain region?

# %%
#Bivariate analysis of continuous variables with region
#visualization
for variable in continuous_variables:
    fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, figsize=fig_dims)
    sns.boxplot(data = df, x = 'region', y = variable )

# %%
#Descriptive stat
for variable in continuous_variables:
    print(variable , df.groupby(["region"])[variable].agg(["mean"]))
    print("")
# Out:
# age_mean                 mean
# region
# northeast  38.064935
# northwest  37.711503
# southeast  38.551746
# southwest  37.824841
#
# bmi                 mean
# region
# northeast  29.363203
# northwest  29.267335
# southeast  32.365695
# southwest  30.777389
#
# bloodpressure                 mean
# region
# northeast  95.722944
# northwest  92.965616
# southeast  94.334081
# southwest  94.079618
#
# claim                    mean
# region
# northeast  16889.044719
# northwest  11672.088453
# southeast  12979.121502
# southwest  12723.129841

# %% [markdown]
# #### Insights:
#     Distribution of bmi in northeast and southwest looks similar. Average BMI of southeast policyhilders is slightly higher than other regions.But for 2 regions bmi is in obese category. So need to check this by hypothesis testing.
#     Distribution of bloodpressure in south regions looks similar but north regions do not show the same
#     Age of policyholders across different region is almost similar. Average age is also similar.

# %% [markdown]
# #### One way Anova   - region & bmi
#       Null Hypothesis H0 – There is no significant difference among the groups
#       Alternate Hypothesis – There is a significant difference among the groups

# %%
southeast= df[df.region=='southeast'].bmi
northeast= df[df.region=='northeast'].bmi
northwest= df[df.region=='northwest'].bmi
southwest= df[df.region=='southwest'].bmi

# %%
# normality tests
print(stats.shapiro(southeast))
print(stats.shapiro(northeast))
print(stats.shapiro(northwest))
print(stats.shapiro(southwest))
# Out:
# ShapiroResult(statistic=0.9925739765167236, pvalue=0.025977209210395813)
# ShapiroResult(statistic=0.9931576251983643, pvalue=0.3671373426914215)
# ShapiroResult(statistic=0.9899710416793823, pvalue=0.017298316583037376)
# ShapiroResult(statistic=0.9955127835273743, pvalue=0.5042665004730225)

# %%
# variance equality test
stats.levene(southeast, northeast, northwest, southwest)
# Out:
# LeveneResult(statistic=6.795601342849626, pvalue=0.00015134241386061668)

# %%
#applying square root transformation
northeast=(northeast)**0.5
northwest=(northwest)**0.5
southeast=(southeast)**0.5
southwest=(southwest)**0.5

# %%
# normality tests
print(stats.shapiro(southeast))
print(stats.shapiro(northeast))
print(stats.shapiro(northwest))
print(stats.shapiro(southwest))
# Out:
# ShapiroResult(statistic=0.995664119720459, pvalue=0.25566333532333374)
# ShapiroResult(statistic=0.9943060278892517, pvalue=0.5344126224517822)
# ShapiroResult(statistic=0.9951844215393066, pvalue=0.35251522064208984)
# ShapiroResult(statistic=0.996414840221405, pvalue=0.7049368023872375)

# %%
#Passed normality test
bmi = list(southeast) +list(northeast) +list(northwest) +list(southwest)
Grand_mean=np.mean(bmi)
print('Grand_mean= ',Grand_mean)
SST= np.sum((bmi-np.mean(bmi))**2)
print("SST= ", SST)
SSW= np.sum((southeast-np.mean(southeast))**2)+np.sum((northeast-np.mean(northeast))**2)+np.sum((southwest-np.mean(southwest))**2)+np.sum((northwest-np.mean(northwest))**2)
print("SSW= ", SSW) #SSW aka SSE
SSA=((np.mean(southeast)-Grand_mean)**2)*len(southeast)+((np.mean(northeast)-Grand_mean)**2)*len(northeast)+((np.mean(northwest)-Grand_mean)**2)*len(northwest)+((np.mean(southwest)-Grand_mean)**2)*len(southwest)
print("SSA= ", SSA)   #SSA aka SSTR
df_w= len(southeast) +len(northeast) +len(northwest) +len(southwest)-4
print("df_w= ", df_w)
df_bet = 4-1
print("df_bet= ", df_bet)
MS_w= SSW/df_w
MS_bet = SSA/df_bet
F_stat= MS_bet/MS_w
print("F_stat= ", F_stat)
p_value = 1 - stats.f.cdf(F_stat, dfn= df_bet, dfd= df_w)
print("p_value= ", p_value)
F_crit=stats.f.isf(0.05 , dfn = df_bet, dfd = df_w)
print("F_crit= ", F_crit)

if F_stat >= F_crit:
    print("Reject H0. So, region affect bmi")
else:
    print("Accept H0. So, region do not affect bmi")
if 0.05 >= p_value:
    print("Reject H0. So, region affect bmi")
else:
    print("Accept H0. So, region do not affect bmi")
# Out:
# Grand_mean=  5.510356550698932
# SST=  408.60071678696175
# SSW=  389.9327993186175
# SSA=  18.66791746834358
# df_w=  1336
# df_bet=  3
# F_stat=  21.320201652941783
# p_value=  1.7175150190951172e-13
# F_crit=  2.611563227252709
# Reject H0. So, region affect bmi
# Reject H0. So, region affect bmi

# %% [markdown]
# #### One way Anova - region & bloodpressure
#       Null Hypothesis H0 – There is no significant difference among the groups
#       Alternate Hypothesis – There is a significant difference among the groups

# %%
southeast= df[df.region=='southeast'].bloodpressure
northeast= df[df.region=='northeast'].bloodpressure
northwest= df[df.region=='northwest'].bloodpressure
southwest= df[df.region=='southwest'].bloodpressure

# %%
# normality tests
print(stats.shapiro(southeast))
print(stats.shapiro(northeast))
print(stats.shapiro(northwest))
print(stats.shapiro(southwest))
# Out:
# ShapiroResult(statistic=0.8793475031852722, pvalue=3.634427297946703e-18)
# ShapiroResult(statistic=0.8851175904273987, pvalue=3.063362280855686e-12)
# ShapiroResult(statistic=0.8906420469284058, pvalue=4.1872235184898556e-15)
# ShapiroResult(statistic=0.8779828548431396, pvalue=4.266288961918361e-15)

# %%
# variance equality test
stats.levene(southeast, northeast, northwest, southwest)
# Out:
# LeveneResult(statistic=5.6847330893067305, pvalue=0.0007227842366044349)

# %%
#applying square root transformation
northeast=(northeast)**0.5
northwest=(northwest)**0.5
southeast=(southeast)**0.5
southwest=(southwest)**0.5

# %%
# normality tests
print(stats.shapiro(southeast))
print(stats.shapiro(northeast))
print(stats.shapiro(northwest))
print(stats.shapiro(southwest))
# Out:
# ShapiroResult(statistic=0.902176558971405, pvalue=2.5521984144432806e-16)
# ShapiroResult(statistic=0.9063186049461365, pvalue=7.574160743040181e-11)
# ShapiroResult(statistic=0.913474440574646, pvalue=2.837139702858982e-13)
# ShapiroResult(statistic=0.9031696319580078, pvalue=2.686565705144195e-13)

# %% [markdown]
# ##### We will have to use here Kruskal Wallis test
#      H0:  southeast, northeast, northwest, southwest all 4 populations are identical distibution (ie all 4 have same probability distribution)
#      H1: Not identical distribution

# %%
result= stats.kruskal(southeast, northwest, northeast, southwest )
print(result)
# Out:
# KruskalResult(statistic=4.61744944028134, pvalue=0.20205028097312194)

# %% [markdown]
# As pvalue is greater than alpha (0.05) hence Accept H0 ie southeast, northeast, northwest, southwest all 4 populations are identical distibution

# %% [markdown]
# ###### Age

# %%
#Bivariate analysis of categorical variables with age
#Visualization
for variable in ['diabetic', 'smoker', 'children']:
#     fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, figsize=fig_dims)
    sns.boxplot(data = df, x = df[variable], y = "age_mean" )

# %%
#Descriptive stat
for variable in ['diabetic', 'smoker', 'children']:
    print( df.groupby([variable])['age_mean'].agg(["mean"]))
# Out:
#                mean
# diabetic
# No        38.355526
# Yes       37.777626
#              mean
# smoker
# No      38.257405
# Yes     37.383212
#                mean
# children
# 0         38.273252
# 1         38.574074
# 2         37.325000
# 3         37.318471
# 4         39.480000
# 5         37.666667

# %%
#Bivariate analysis of continuous variables with age
for variable in ['bmi', 'bloodpressure']:
    sns.regplot(x= 'age_mean', y=variable, data=df)
    plt.legend(loc=(0))
    plt.figure(figsize=(8, 4))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ###### smoker

# %%
#Bivariate analysis of discrete & categorical variables with smoker
#Visualization
pd.crosstab(df['smoker'], df['diabetic']).plot(kind='bar', stacked=True)
pd.crosstab(df['children'], df['smoker']).plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='children'>

# %%
#Descriptive stats

print(pd.crosstab(index=df['smoker'], columns=df['diabetic'],normalize="index"))
print("")
print(pd.crosstab(index=df['children'], columns=df['smoker'],normalize="index"))
# Out:
# diabetic        No       Yes
# smoker
# No        0.525328  0.474672
# Yes       0.503650  0.496350
#
# smoker          No       Yes
# children
# 0         0.800347  0.199653
# 1         0.811728  0.188272
# 2         0.770833  0.229167
# 3         0.751592  0.248408
# 4         0.880000  0.120000
# 5         0.944444  0.055556

# %%
#Bivariate analysis of continuous variables with region
#visualization
for variable in ['bmi', 'bloodpressure']:
    fig_dims = (10, 5)
    fig, axs = plt.subplots(nrows=1, figsize=fig_dims)
    sns.boxplot(data = df, x = 'smoker', y = variable )

# %%
#Descriptive stat
for variable in ['bmi', 'bloodpressure']:
    print(variable , df.groupby(["smoker"])[variable].agg(["mean"]))
    print("")
# Out:
# bmi              mean
# smoker
# No      30.657598
# Yes     30.713139
#
# bloodpressure               mean
# smoker
# No       91.733583
# Yes     103.587591

# %%
#1.
plt.figure(figsize=(15,7))
sns.lineplot(df["age_mean"],df["claim"],hue=df["gender"],ci=0).set(title= 'Cost incured by Age for Female and Males')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
#     Sudden spike in claim for women at the age of around 30
#     Sudden spike in claim for men at the age of around 22 and sudden down around 38

# %%
#2
fig1 = plt.figure(figsize=[9,6]);
ax0 = sns.scatterplot(data=df, x = 'age_mean', y = 'claim', hue='smoker');
plt.xlabel('Age', fontsize='14', fontweight='bold');
plt.ylabel('Claim', fontsize='14', fontweight='bold');
plt.title('Relationship of Age to claim to Smoking', fontsize='16', fontweight='bold');

# %% [markdown]
# ##### Can't see any such relation in visualization hence doing descriptive statistics

# %%
#creating groups for age
category1=pd.cut(df.age_mean,bins=[18,40,60],labels=['18-40','40-60'])
df.insert(6,'AgeBin',category1)

# %%
# smoking policyholder with different age and gender have diffrent claim amount? 
df.groupby(['AgeBin', 'gender' ,'smoker']).mean()['claim'].unstack()
# Out:
# smoker                  No           Yes
# AgeBin gender
# 18-40  female  8793.681590  30584.788571
#        male    8218.805113  32531.310885
# 40-60  female  8737.944026  30748.938333
#        male    7679.160733  33970.458000

# %% [markdown]
# smoking policyholders in the age group of (40-60) have higher claim amount as compared to age group of (18-40).

# %%
#3
fig1 = plt.figure(figsize=[9,6]);
ax0 = sns.scatterplot(data=df, y = 'claim', x = 'bmi', hue='smoker');
plt.xlabel('Body Mass Index', fontsize='14', fontweight='bold');
plt.ylabel('Claim', fontsize='14', fontweight='bold');
plt.title('Relationship of BMI to Claim to Smoking', fontsize='16', fontweight='bold');

# %% [markdown]
# Smoking and Obesity are directly proportional to the claim amount. All things equal, a smoker with a higher BMI will cost more than a non-smoker with the same BMI.

# %%
#making groups for BMI
category=pd.cut(df.bmi,bins=[15,25,35,45,55],labels=['0-18.49','18.5-24.9','25-29.9','30-55'])
df.insert(5,'BMIGroup',category)

# %%
df.head()
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0   male  23.2             91      Yes         0    0-18.49     No  18-40
# 1   male  30.1             87       No         0  18.5-24.9     No  18-40
# 2   male  33.3             82      Yes         0  18.5-24.9     No  18-40
# 3   male  33.7             80       No         0  18.5-24.9     No  18-40
# 4   male  34.1            100       No         0  18.5-24.9     No  18-40
#
#       region    claim   age_mean
# 0  southeast  1121.87  39.000000
# 1  southeast  1131.51  24.000000
# 2  southeast  1135.94  38.078652
# 3  northwest  1136.40  38.078652
# 4  northwest  1137.01  38.078652

# %%
df.groupby(df.BMIGroup).claim.mean()
# Out:
# BMIGroup
# 0-18.49      10249.694476
# 18.5-24.9    12720.254413
# 25-29.9      16860.603401
# 30-55        17547.927500
# Name: claim, dtype: float64

# %%
#4
df.groupby(['gender','BMIGroup']).mean()['claim'].unstack()
# Out:
# BMIGroup       0-18.49     18.5-24.9       25-29.9         30-55
# gender
# female    10912.823130  11999.488151  14937.032302  25928.807500
# male       9507.217094  13428.116931  18552.858987  11960.674167

# %% [markdown]
#     Claim amount for female underweight and obese policyholder is more than male underweight & obese policyholder
#     Female-obese is costing really high

# %%
df.columns
# Out:
# Index(['gender', 'bmi', 'bloodpressure', 'diabetic', 'children', 'BMIGroup',
#        'smoker', 'AgeBin', 'region', 'claim', 'age_mean'],
#       dtype='object')

# %% [markdown]
# ## Conclusions of EDA & Hypothesis testing done so far to get idea about significant features affecting claim & new feature generation

# %% [markdown]
# ### 7. Converting smoker & nosmoker using one hot encoding

# %%
data=df.copy()

# %%
# data['smoker']= pd.get_dummies(data['smoker'],drop_first=True).head()#get dummies is a function

# %%
for i in range (0, len(data)):
    if data['smoker'][i]=="Yes":
        data['smoker'][i] =1
    else:
        data['smoker'][i]=0

# %%
data.head() #yes-1, no-0
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0   male  23.2             91      Yes         0    0-18.49      0  18-40
# 1   male  30.1             87       No         0  18.5-24.9      0  18-40
# 2   male  33.3             82      Yes         0  18.5-24.9      0  18-40
# 3   male  33.7             80       No         0  18.5-24.9      0  18-40
# 4   male  34.1            100       No         0  18.5-24.9      0  18-40
#
#       region    claim   age_mean
# 0  southeast  1121.87  39.000000
# 1  southeast  1131.51  24.000000
# 2  southeast  1135.94  38.078652
# 3  northwest  1136.40  38.078652
# 4  northwest  1137.01  38.078652

# %%
# data['gender']= pd.get_dummies(data['gender'],drop_first=True).head()#get dummies is a function

# %%
for i in range (0, len(data)):
    if data['gender'][i]== "male":
        data['gender'][i] =1
    else:
        data['gender'][i]=0

# %%
data.head()  #1-male, 0-female
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0      1  23.2             91      Yes         0    0-18.49      0  18-40
# 1      1  30.1             87       No         0  18.5-24.9      0  18-40
# 2      1  33.3             82      Yes         0  18.5-24.9      0  18-40
# 3      1  33.7             80       No         0  18.5-24.9      0  18-40
# 4      1  34.1            100       No         0  18.5-24.9      0  18-40
#
#       region    claim   age_mean
# 0  southeast  1121.87  39.000000
# 1  southeast  1131.51  24.000000
# 2  southeast  1135.94  38.078652
# 3  northwest  1136.40  38.078652
# 4  northwest  1137.01  38.078652

# %%
# data['diabetic']= pd.get_dummies(data['diabetic'],drop_first=True).head()#get dummies is a function

# %%
for i in range (0, len(data)):
    if data['diabetic'][i]== "Yes":
        data['diabetic'][i] =1
    else:
        data['diabetic'][i]=0

# %%
data.head()  # Yes-1 , No-0
# Out:
#    gender   bmi  bloodpressure  diabetic  children   BMIGroup  smoker AgeBin  \
# 0     1.0  23.2             91       1.0         0    0-18.49     0.0  18-40
# 1     1.0  30.1             87       0.0         0  18.5-24.9     0.0  18-40
# 2     1.0  33.3             82       1.0         0  18.5-24.9     0.0  18-40
# 3     1.0  33.7             80       0.0         0  18.5-24.9     0.0  18-40
# 4     1.0  34.1            100       0.0         0  18.5-24.9     0.0  18-40
#
#       region    claim   age_mean
# 0  southeast  1121.87  39.000000
# 1  southeast  1131.51  24.000000
# 2  southeast  1135.94  38.078652
# 3  northwest  1136.40  38.078652
# 4  northwest  1137.01  38.078652

# %% [markdown]
# ### 1. From point 4, Average claim amount of northeast is high as compared to other 3 regions, Other 3 have similar amount

# %%
region=[]
for r in data['region']:
    if r=='northeast':
        region.append(1)
    else:
        region.append(0)

# %%
data['region']=pd.DataFrame(region)
data
# Out:
#      gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0         1  23.2             91        1         0    0-18.49      0  18-40
# 1         1  30.1             87        0         0  18.5-24.9      0  18-40
# 2         1  33.3             82        1         0  18.5-24.9      0  18-40
# 3         1  33.7             80        0         0  18.5-24.9      0  18-40
# 4         1  34.1            100        0         0  18.5-24.9      0  18-40
# ...     ...   ...            ...      ...       ...        ...    ...    ...
# 1335      0  35.5             88        1         0    25-29.9      1  40-60
# 1336      0  38.1            120        0         1    25-29.9      1  40-60
# 1337      1  34.5             91        1         3  18.5-24.9      1  18-40
# 1338      1  30.4            106        0         0  18.5-24.9      1  18-40
# 1339      0  47.4            101        0         0      30-55      1  18-40
#
#       region      claim   age_mean
# 0          0   1121.870  39.000000
# 1          0   1131.510  24.000000
# 2          0   1135.940  38.078652
# 3          0   1136.400  38.078652
# 4          0   1137.010  38.078652
# ...      ...        ...        ...
# 1335       0  34431.235  44.000000
# 1336       1  34431.235  59.000000
# 1337       0  34431.235  30.000000
# 1338       0  34431.235  37.000000
# 1339       0  34431.235  30.000000
#
# [1340 rows x 11 columns]

# %% [markdown]
# ### 2. From point 6, bloodpressure < 100 , claim amount below Rs 15000 approx.
# ### between 100 to 110, 25000 > claim amount > Rs 10000 approx
# ###  bloodpressure > 110 are costing really high

# %%
data["BP_1"] = 0
data["BP_2"] = 0 
data["BP_3"] = 0
for bp in data['bloodpressure']:
    if bp <= 100:
        data["BP_1"] = 1
        data["BP_2"] = 0
        data["BP_3"] = 0        
        
    elif 100 < bp <= 110:
        data["BP_1"] = 0
        data["BP_2"] = 1
        data["BP_3"] = 0
    else:
        data["BP_1"] = 0
        data["BP_2"] = 0
        data["BP_3"] = 1

# %%
data.head()
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0      1  23.2             91        1         0    0-18.49      0  18-40
# 1      1  30.1             87        0         0  18.5-24.9      0  18-40
# 2      1  33.3             82        1         0  18.5-24.9      0  18-40
# 3      1  33.7             80        0         0  18.5-24.9      0  18-40
# 4      1  34.1            100        0         0  18.5-24.9      0  18-40
#
#    region    claim   age_mean  BP_1  BP_2  BP_3
# 0       0  1121.87  39.000000     0     1     0
# 1       0  1131.51  24.000000     0     1     0
# 2       0  1135.94  38.078652     0     1     0
# 3       0  1136.40  38.078652     0     1     0
# 4       0  1137.01  38.078652     0     1     0

# %% [markdown]
# ### 3. From point 7, policyholders with 0 &1 children have similar claim amount while 2, 3,4,5 have similar claim amount.

# %%
children=[]
for c in data['children']:
    if c== 0 or c==1:
        children.append(0)
    else:
        children.append(1)
# 0 for 0 &1 and 1 for 2,3,4,5

# %%
data['children']=pd.DataFrame(children)
data
# Out:
#      gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0         1  23.2             91        1         0    0-18.49      0  18-40
# 1         1  30.1             87        0         0  18.5-24.9      0  18-40
# 2         1  33.3             82        1         0  18.5-24.9      0  18-40
# 3         1  33.7             80        0         0  18.5-24.9      0  18-40
# 4         1  34.1            100        0         0  18.5-24.9      0  18-40
# ...     ...   ...            ...      ...       ...        ...    ...    ...
# 1335      0  35.5             88        1         0    25-29.9      1  40-60
# 1336      0  38.1            120        0         0    25-29.9      1  40-60
# 1337      1  34.5             91        1         1  18.5-24.9      1  18-40
# 1338      1  30.4            106        0         0  18.5-24.9      1  18-40
# 1339      0  47.4            101        0         0      30-55      1  18-40
#
#       region      claim   age_mean  BP_1  BP_2  BP_3
# 0          0   1121.870  39.000000     0     1     0
# 1          0   1131.510  24.000000     0     1     0
# 2          0   1135.940  38.078652     0     1     0
# 3          0   1136.400  38.078652     0     1     0
# 4          0   1137.010  38.078652     0     1     0
# ...      ...        ...        ...   ...   ...   ...
# 1335       0  34431.235  44.000000     0     1     0
# 1336       1  34431.235  59.000000     0     1     0
# 1337       0  34431.235  30.000000     0     1     0
# 1338       0  34431.235  37.000000     0     1     0
# 1339       0  34431.235  30.000000     0     1     0
#
# [1340 rows x 14 columns]

# %% [markdown]
# ### 4. From point 11, smoking policyholders in the age group of (40-60) have higher claim amount as compared to age group of (18-40).

# %%
data.groupby(['AgeBin','smoker']).mean()['claim']
# Out:
# AgeBin  smoker
# 18-40   0          8449.271526
#         1         28308.695926
# 40-60   0          8381.075218
#         1         27929.041667
# Name: claim, dtype: float64

# %%
data["smok_age40"] = 0
data["smok_age60"] = 0
for i in range(0, len(data)):
    if data['smoker'][i]==1 and data['age_mean'][i] <= 40:
        data["smok_age40"][i] = 1
    elif data['smoker'][i] ==1 and data['age_mean'][i] > 40:
        data["smok_age60"][i] = 1
data.head()
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0      1  23.2             91        1         0    0-18.49      0  18-40
# 1      1  30.1             87        0         0  18.5-24.9      0  18-40
# 2      1  33.3             82        1         0  18.5-24.9      0  18-40
# 3      1  33.7             80        0         0  18.5-24.9      0  18-40
# 4      1  34.1            100        0         0  18.5-24.9      0  18-40
#
#    region    claim   age_mean  BP_1  BP_2  BP_3  smok_age40  smok_age60
# 0       0  1121.87  39.000000     0     1     0           0           0
# 1       0  1131.51  24.000000     0     1     0           0           0
# 2       0  1135.94  38.078652     0     1     0           0           0
# 3       0  1136.40  38.078652     0     1     0           0           0
# 4       0  1137.01  38.078652     0     1     0           0           0

# %% [markdown]
# ### 5. From point 12, All things equal, a smoker with a higher BMI will cost more than a non-smoker with the same BMI.

# %%
data["nosmoke_anyBmi"] = 0
data["smok_bmi_l30"] = 0
data["smok_bmi_H30"] = 0

for i in range(0, len(data)):
    if data['smoker'][i]==0:
        data["nosmoke_anyBmi"][i] = 1
    elif data['smoker'][i] ==1 and data['bmi'][i] < 30:
        data["smok_bmi_l30"][i] = 1
    elif data['smoker'][i] ==1 and data['bmi'][i] >= 30:
        data["smok_bmi_H30"][i] = 1
        
data.head()
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0      1  23.2             91        1         0    0-18.49      0  18-40
# 1      1  30.1             87        0         0  18.5-24.9      0  18-40
# 2      1  33.3             82        1         0  18.5-24.9      0  18-40
# 3      1  33.7             80        0         0  18.5-24.9      0  18-40
# 4      1  34.1            100        0         0  18.5-24.9      0  18-40
#
#    region    claim   age_mean  BP_1  BP_2  BP_3  smok_age40  smok_age60  \
# 0       0  1121.87  39.000000     0     1     0           0           0
# 1       0  1131.51  24.000000     0     1     0           0           0
# 2       0  1135.94  38.078652     0     1     0           0           0
# 3       0  1136.40  38.078652     0     1     0           0           0
# 4       0  1137.01  38.078652     0     1     0           0           0
#
#    nosmoke_anyBmi  smok_bmi_l30  smok_bmi_H30
# 0               1             0             0
# 1               1             0             0
# 2               1             0             0
# 3               1             0             0
# 4               1             0             0

# %% [markdown]
# ### 6. Everything aside, female obese are costing really high than any other else is

# %%
data["female_obese"] = 0

for i in range(0, len(data)):
    if data['gender'][i]==0 and data['bmi'][i] >= 30:
        data["female_obese"] = 1
        
data.head()
# Out:
#   gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 0      1  23.2             91        1         0    0-18.49      0  18-40
# 1      1  30.1             87        0         0  18.5-24.9      0  18-40
# 2      1  33.3             82        1         0  18.5-24.9      0  18-40
# 3      1  33.7             80        0         0  18.5-24.9      0  18-40
# 4      1  34.1            100        0         0  18.5-24.9      0  18-40
#
#    region    claim   age_mean  BP_1  BP_2  BP_3  smok_age40  smok_age60  \
# 0       0  1121.87  39.000000     0     1     0           0           0
# 1       0  1131.51  24.000000     0     1     0           0           0
# 2       0  1135.94  38.078652     0     1     0           0           0
# 3       0  1136.40  38.078652     0     1     0           0           0
# 4       0  1137.01  38.078652     0     1     0           0           0
#
#    nosmoke_anyBmi  smok_bmi_l30  smok_bmi_H30  female_obese
# 0               1             0             0             1
# 1               1             0             0             1
# 2               1             0             0             1
# 3               1             0             0             1
# 4               1             0             0             1

# %% [markdown]
# ### Doing the train test split

# %%
y = data["claim"]
X = data.drop("claim",axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2,random_state = 0)

# %%
y_train=pd.DataFrame(y_train)

# %% [markdown]
# ### 7. Feature Tranformation

# %%
#### to check whether feature is guassian ie  whethere feature is normal distributed ---using Q-Q plot
#### Q-Q plot
import scipy.stats as stat
import pylab 
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    df[feature].hist()
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)  #yaxiswill have normally distributed data  
    plt.xlabel(feature) #labeling x axis    
    plt.show()
    #Right hand side plot isQ-Q plot & in this plot, if data falls on a straight line then we say it is in gaussian distribution

# %%
plot_data(X_train, 'bloodpressure')

# %%
X_train['bloodpressure']=np.log(X_train['bloodpressure']) #applying np.log on every feature(because right skewed)
plot_data(X_train, 'bloodpressure')

# %%
plot_data(y_train,'claim')

# %%
y_train['claim']=np.log(y_train['claim']) #applying np.log on every feature(because right skewed)
plot_data(y_train,'claim')

# %%
X_train['Age_Boxcox'],parameters=stat.boxcox(X_train['age_mean']) #here parameter is  λ

# %%
plot_data(X_train,'Age_Boxcox')

# %% [markdown]
# ### Selection

# %%
X_train_b =X_train.copy()
X_train_b=X_train_b[['gender', 'bmi', 'bloodpressure', 'diabetic', 'children',
       'smoker', 'region', 'age_mean', 'BP_1', 'BP_2', 'BP_3',
       'smok_age40', 'smok_age60', 'nosmoke_anyBmi', 'smok_bmi_l30',
       'smok_bmi_H30', 'female_obese', 'Age_Boxcox']]
y_train_b =y_train['claim']

# %%
X_train_b.dtypes
# Out:
# gender             object
# bmi               float64
# bloodpressure     float64
# diabetic           object
# children            int64
# smoker             object
# region              int64
# age_mean          float64
# BP_1                int64
# BP_2                int64
# BP_3                int64
# smok_age40          int64
# smok_age60          int64
# nosmoke_anyBmi      int64
# smok_bmi_l30        int64
# smok_bmi_H30        int64
# female_obese        int64
# Age_Boxcox        float64
# dtype: object

# %% [markdown]
# ### Firstly let's deal with Outliers

# %%
# BMI
# Assuming bmi follows ~ Gaussian Distribution,calculating the boundaries which differentiates the outliers
uppper_boundary=df['bmi'].mean() + 3* df['bmi'].std()
lower_boundary=df['bmi'].mean() - 3* df['bmi'].std()
print(lower_boundary), print(uppper_boundary),print(df['bmi'].mean())
# Out:
# 12.34875092335458
# 48.989159524406595
# 30.668955223880587
# (None, None, None)

# %%
df.loc[df['bmi']>=48.98]
# Out:
#      gender   bmi  bloodpressure diabetic  children BMIGroup smoker AgeBin  \
# 9      male  53.1             97       No         0    30-55     No  18-40
# 141    male  50.4             89      Yes         1    30-55     No  40-60
# 802    male  49.1            109      Yes         0    30-55     No  40-60
# 1299   male  52.6            110       No         1    30-55    Yes  40-60
#
#          region     claim  age_mean
# 9     northwest   1163.46      30.0
# 141   southeast   2438.06      46.0
# 802   southeast  11381.33      42.0
# 1299  southeast  44501.40      50.0

# %% [markdown]
# For bmi we can see that max value is 53.1 bmi which is non-error outlier. Hence it's our population interest not an anomaly, So not removing
# We are replacing it.

# %%
#Replacing
# data=df.copy()
df.loc[df['bmi']>48.989159524406595,'bmi']=48.989159524406595

# %%
#checking 
# df['bmi'].describe(), data['bmi'].describe()

# %%
# figure=data.bmi.hist(bins=50)
figure=df.bmi.hist(bins=50)

# %%
#Bloodpressure
# As distribution of bloodpressure is skewed, boundries are-

IQR = df.bloodpressure.quantile(0.75)-df.bloodpressure.quantile(0.25) #computing the Interquantile range to calculate the boundaries

lower_bridge=df['bloodpressure'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['bloodpressure'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 66.5
# 118.5
# (None, None)

# %% [markdown]
# It is giving maximum bloodpressure as 118.5 but normal bloodpressure itself is 120 hence calculating extreme outlier

# %%
#### Extreme outliers
lower_bridge=df['bloodpressure'].quantile(0.25)-(IQR*3)
upper_bridge=df['bloodpressure'].quantile(0.75)+(IQR*3)
print(lower_bridge), print(upper_bridge)
# Out:
# 47.0
# 138.0
# (None, None)

# %%
df.loc[df['bloodpressure']>=138.0]
# Out:
#       gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 1174  female  29.1            139       No         0  18.5-24.9    Yes  40-60
# 1210    male  30.8            140      Yes         0  18.5-24.9    Yes  18-40
# 1225  female  34.8            140      Yes         2  18.5-24.9     No  40-60
# 1226    male  35.5            140      Yes         0    25-29.9    Yes  40-60
# 1230  female  30.8            139       No         0  18.5-24.9    Yes  40-60
# 1242  female  36.7            140       No         2    25-29.9    Yes  18-40
# 1254    male  44.9            138      Yes         0    25-29.9    Yes  40-60
# 1256    male  30.9            139       No         0  18.5-24.9    Yes  18-40
# 1257    male  36.7            139      Yes         1    25-29.9    Yes  40-60
# 1290    male  41.9            140      Yes         3    25-29.9    Yes  40-60
#
#          region     claim  age_mean
# 1174  northwest  29141.36      44.0
# 1210  southwest  35491.64      25.0
# 1225  southwest  36910.61      50.0
# 1226  southeast  36950.26      46.0
# 1230  northeast  37270.15      58.0
# 1242  northeast  38511.63      27.0
# 1254  southeast  39722.75      46.0
# 1256  southwest  39727.61      27.0
# 1257  northeast  39774.28      43.0
# 1290  northeast  43753.34      47.0

# %%
#Replacing
# data=df.copy()
df.loc[df['bloodpressure']>138,'bloodpressure']=138

# %%
# df['bloodpressure'].describe(), data['bloodpressure'].describe()

# %%
# figure=data.bloodpressure.hist(bins=50)
figure=df.bloodpressure.hist(bins=50)

# %%
#claim
# As distribution of claim is skewed, boundries are-

IQR=df.claim.quantile(0.75)-df.claim.quantile(0.25) #computing the Interquantile range to calculate the boundaries

lower_bridge=df['claim'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['claim'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# -13107.245
# 34431.235
# (None, None)

# %%
df.loc[df['claim']>=34431.235]
# Out:
#       gender   bmi  bloodpressure diabetic  children   BMIGroup smoker AgeBin  \
# 1199  female  33.1             93      Yes         0  18.5-24.9    Yes  18-40
# 1200    male  32.7             98       No         0  18.5-24.9    Yes  18-40
# 1201    male  33.5             81       No         0  18.5-24.9    Yes  40-60
# 1202    male  31.7            125       No         0  18.5-24.9    Yes  18-40
# 1203    male  34.8             94      Yes         0  18.5-24.9    Yes  18-40
# ...      ...   ...            ...      ...       ...        ...    ...    ...
# 1335  female  35.5             88      Yes         0    25-29.9    Yes  40-60
# 1336  female  38.1            120       No         1    25-29.9    Yes  40-60
# 1337    male  34.5             91      Yes         3  18.5-24.9    Yes  18-40
# 1338    male  30.4            106       No         0  18.5-24.9    Yes  18-40
# 1339  female  47.4            101       No         0      30-55    Yes  18-40
#
#          region     claim  age_mean
# 1199  southeast  34439.86      30.0
# 1200  southwest  34472.84      40.0
# 1201  northeast  34617.84      45.0
# 1202  southeast  34672.15      32.0
# 1203  southwest  34779.62      26.0
# ...         ...       ...       ...
# 1335  northwest  55135.40      44.0
# 1336  northeast  58571.07      59.0
# 1337  northwest  60021.40      30.0
# 1338  southeast  62592.87      37.0
# 1339  southeast  63770.43      30.0
#
# [141 rows x 11 columns]

# %%
#Replacing
# data=df.copy()
df.loc[df['claim']>34431.235,'claim']=34431.235

# %%
# df['claim'].describe(), data['claim'].describe()

# %%
# figure=data.claim.hist(bins=50)
figure=df.claim.hist(bins=50)

# %% [markdown]
# Feature transformation, Engineering, Selection
# Regression assumptions – before fitting model
# Train, test split
# Fit model(s)

# %%
df.columns
# Out:
# Index(['gender', 'bmi', 'bloodpressure', 'diabetic', 'children', 'BMIGroup',
#        'smoker', 'AgeBin', 'region', 'claim', 'age_mean'],
#       dtype='object')

# %% [markdown]
# 1. Average claim amount is similar for female & female
# 2. Average claim amount for diabetic & non-diabetic is almost same
# 3. Average claim amount of smoker is very high than non-smoker.
# 4. Average claim amount of northeast is high as compared to other 3 regions, Other 3 have similar amount
# 5. As BMI increaing Claim amount increases
# 6. As Bloodpressure increases claim amount increases
# 7. policyholders with 0 &1 children have similar claim amount while 3,4,5 have similar claim amount. If we see boxplots of policyholders with number of children & claim amount, Incresing trend in claim as number of children increases upto 3 and later decreases for 4&5 It may be because uneven distribution of data. As observations for policyholders with 4&5 number of children are very less.
#
# Gender influences smoking
# Average BMI of male & female are almost same. Distribution also looks similar.
# Average bloodpressure of male & female is almost same. Distribution is also similar
# Average age of female is higher than male.
# Proportion of smokers is more in northeast & for all other regions ,region is not influencing smoking
# region affect bmi
# More proportion of smokers in policyholders who are diabetic as compared to policyholders who don't smoke
# As the policyholder's number of children increases smoking proportion also increases
# smokers have slightly higher bmi
# Policyholders who smoke have higher bloodpressure
# smoking policyholders in the age group of (40-60) have higher claim amount as compared to age group of (18-40).
# All things equal, a smoker with a higher BMI will cost more than a non-smoker with the same BMI.
# Female-obese(bmi >30) is costing really high

# %%
 bloodpressure- highly right skewed

# %% [markdown]
# Age
#
#     range= 18 to 60 #whole age group is covered which is good
#     mean ~ median So, distribution is symmetric & our distribution will have almost zero skewness
#     median - 38
#     age distribution is fairly symmetrical
#     Platykurtic- So more variability in age ie more range of values but frequency of values is less. Good, better Predictability.
#     SD ~ 11
#     CV = 3.436 --So standard deviation is very higher than mean. so data is more spread out wrt to mean.
#     Age has a broad maximum plateau in the middle. This is expected as people in age group 30-50 are most likely to take insurance policy
#     No outliers.
#
# BMI
#
#     range= 16 to 53 ...Good!
#     mean ~ median
#     median = 30, So, 50% of policyholders are in obese category
#     mean -30.66 which falls in obese category
#     25th percentile- 26 bmi, Hence more than 75 % of policyholders do not have normal bmi.
#     Distribution is fairly symmetrical
#     platykurtic.....Good!
#     SD~ 6
#     CV= 5.02
#     Outliers present on upper side
#
# Bloodpressure
#
#     According to the distribution of bloodpressure, it is diastolyc bloodpressure.
#     So normal range - 60 to 80 mmHg.
#     Stage1 hypertension: 80-89
#     stage2 hypertension: 90 or more
#     Hypertension crisis: 120 or more
#
#     range= 80 to 140
#     mean = 94.16
#     mean != median
#     median = 92
#     distribution is highly right skewed
#     platykurtic
#     No policyholder has normal bloodpressure range. around, 50% of policyholders have stage 2 hypertension
#     SD ~11
#     CV= 8.23
#     Outliers present
#     according to the distribution it looks like systolic bloodpressure
#     lot of outliers on upper side
#
#
# Claim
#
#     range =1122 to 63770
#     mean != median
#     median ~ 9370
#     distribution is highly right skewed, bump around 40000
#     platykurtic
#     SD ~ 12109
#     CV= 1.09
#     lot of outliers present on upper end
